# %%
import cv2
import pandas as pd
import numpy as np

# %%
image = cv2.imread(filename="img2.jpg", flags=1)
print(image.shape)
cv2.imshow("img", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (375, 500, 3)

# %%
h,w = image.shape[:2]
center_x,center_y = int((w/2)),int((h/2))
center_x,center_y
# Out:
# (250, 187)

# %%
left = image[:,:center_x]
right = image[:,center_x:]
top = image[:center_y,:]
down = image[center_y:,:]
topleft = image[0:center_y,0:center_x]
topright = image[0:center_y,center_x:w]
bottom_left = image[center_y:h,0:center_x]
bottom_right = image[center_y:,center_x:]

# %%
print(left.shape)
print(right.shape)
print(top.shape)
print(down.shape)
print(topleft.shape)
print(topright.shape)
print(bottom_left.shape)
print(bottom_right.shape)
# Out:
# (375, 250, 3)
# (375, 250, 3)
# (187, 500, 3)
# (188, 500, 3)
# (187, 250, 3)
# (187, 250, 3)
# (188, 250, 3)
# (188, 250, 3)

# %%
cv2.imshow("img", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow("img", left)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow("img", right)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow("img", top)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow("img", down)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow("img", topleft)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow("img", topright)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow("img", bottom_left)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow("img", bottom_right)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.selectROI("Window_name", image)
# Out:
# (84, 23, 295, 317)

# %%
from typing import Union,Optional,Any,List,ByteString
from nptyping import NDArray
@property
def base64toimage(self) -> NDArray[np.uint8]  :

    image = Image.open(self.bytesObj)
    del self.bytesObj
#        img_cv = cv2.cvtColor(np.array(img),cv2.COLOR_RGB2BGR) #https://stackoverflow.com/questions/14134892/convert-image-from-pil-to-opencv-format
    (im_width, im_height) = image.size
    return np.array(image.getdata()).reshape(
        (im_height, im_width, 3)).astype(np.uint8)

#        return img_cv

@base64toimage.setter
def base64toimage(self,img_strings:Optional[bytes]) :
    base64str = base64.b64decode(img_strings)
    self.bytesObj = io.BytesIO(base64str) # we used self bytesObj because it size of bytes is less than cv2 so we used 


def _imagetobase64(self,ImageArray:NDArray[Any]) -> ByteString:

    img_RGB = cv2.cvtColor(ImageArray,cv2.COLOR_BGR2RGB)
    image_array = Image.fromarray(img_RGB)
    buffered = io.BytesIO()
    image_array.save(buffered,format="png")
    bas64str = base64.b64encode(buffered.getvalue()).decode('utf-8') #https://stackoverflow.com/questions/31826335/how-to-convert-pil-image-image-object-to-base64-string

    return bas64str

# %%
image = "..."

# %%
import base64
imgdata = base64.b64decode(image)

# %%
with open('fileName', 'wb') as f:
        f.write(imgdata)
        f.close()

# %%
im1 = base64toimage

# %%
# import requests module
import requests
 
# Making a get request
response = requests.get('https://api.github.com')
 
# print response
print(response)
 
# print json content
print(response.json())
# Out:
# <Response [200]>
# ...

# %%
image = cv2.imread(filename="img2.jpg", flags=1)
print(image.shape)
cv2.imshow("img", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (375, 500, 3)

# %%
percent_crop = 0.1
img = image
if percent_crop > 0.0:
    height,width,_ = img.shape
    cut_pixel_height_side = int(percent_crop*height)//2
    cut_pixel_width_side = int(percent_crop*width)//2

    crop_img = img[cut_pixel_height_side : -cut_pixel_height_side , cut_pixel_width_side : -cut_pixel_width_side]
    cv2.imshow("img", crop_img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

#    crop_predict_img = self.run_inference(crop_img,thresholds)
#    img[cut_pixel_height_side : -cut_pixel_height_side , cut_pixel_width_side : -cut_pixel_width_side] = crop_predict_img 

else:
    normal_img = img

# %%
crop_img.shape
# Out:
# (339, 450, 3)

# %%
cut_pixel_height_side
# Out:
# 18

# %%
cut_pixel_height_side
# Out:
# 18

# %%
cut_pixel_width_side
# Out:
# 25

# %%
img.shape
# Out:
# (375, 500, 3)

# %%
a = img[10:-10,:]
a.shape
# Out:
# (355, 500, 3)

# %%
img.shape
# Out:
# (375, 500, 3)

# %%
x_axis = (0.1,0.8) 
y_axis = (0.1,0.8)

# %%
x_axis[1]
# Out:
# 0.8

# %%
if isinstance(x_axis,Tuple):
    print("x_pass")
if isinstance(y_axis,Tuple):
    print("y_pass")
# Out:
# x_pass
# y_pass

# %%
from typing import Dict,ByteString,Tuple

if isinstance(x_axis,Tuple) or isinstance(y_axis,Tuple):
    height,width,_ = img.shape

    if isinstance(x_axis,tuple):
        start_pixel_width = int(width*x_axis[0])
        end_pixel_width = int(width*x_axis[1])
        cut_img_width = img[ : ,   start_pixel_width: end_pixel_width]
        print("before shape is ",img.shape)
        print("after shape is ",cut_img_width.shape)
        print("width1 cut")

    if isinstance(y_axis,tuple):
        start_pixel_height = int(height*y_axis[0])
        end_pixel_height = int(height*y_axis[1])

        if isinstance(x_axis,tuple):
            cut_img_height_width =   cut_img_width[start_pixel_height: end_pixel_height]
            print("before shape is ",img.shape)
            print("after shape is ",cut_img_height_width.shape)
            print("height1 cut")
#            cut_img = self.inference(cut_img_height_width)
        else:
            cut_img_height = img[  start_pixel_height:   end_pixel_height]
            print("height2 cut")
            # cv.imwrite('width.jpg', cut_img_height)
#            cut_img = self.inference(cut_img_height)

    elif isinstance(x_axis,tuple):
        pass
#        cut_img = self.inference(cut_img_width)


else:
    normal_img = img
#    img = self.inference(normal_img)
# Out:
# before shape is  (375, 500, 3)
# after shape is  (375, 350, 3)
# width1 cut
# before shape is  (375, 500, 3)
# after shape is  (263, 350, 3)
# height1 cut

# %%
start_pixel_width,end_pixel_width
# Out:
# (50, 50)

# %%
375/10
# Out:
# 37.5

# %%
37.5 * 8 -37.5
# Out:
# 262.5

# %%
img = cv2.imread("output.jpg")
img.shape
# Out:
# (263, 350, 3)

# %%
cv2.imshow("img", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np


blurred_img = cv2.GaussianBlur(img, (21, 21), 0)

cv2.imshow("img", blurred_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.selectROI("Window_name", img)
# Out:
# (12, 54, 334, 163)

# %%
blurred_img1 = blurred_img

# %%
h,w = blurred_img.shape[:2]

half_width = w/2
half_width = int(half_width)
half_width
# Out:
# 175

# %%
blurred_img1[:,:half_width] = img[:,:half_width]

# %%
cv2.imshow("img", blurred_img1)
cv2.waitKey(0)
cv2.destroyAllWindows()
